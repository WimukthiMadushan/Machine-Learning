# %% [markdown]
# # Single Variable Linear Regression

# %%
import numpy as np
import pandas as pd

# %%
# Load the data
data = pd.read_csv('Book1.csv')
data
# Out:
#   Unnamed: 0  videos  views
# 0   channel1      30  34000
# 1   channel2      40  41000
# 2   channel3      50  42500
# 3   channel4      60  54300
# 4   channel5      70  56000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.videos, data.views, color='red')
plt.title('Videos vs Views')
plt.xlabel('Number of videos')
plt.ylabel('Number of views')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
x= np.array(data.videos.values)
y= np.array(data.views.values)
model = LinearRegression()

# %%
model.fit(x.reshape(-1,1), y)
# Out:
# LinearRegression()

# %%
pred = model.predict([[45]])

# %%
pred
# Out:
# array([42695.])

# %%
plt.scatter(data.videos, data.views, color='red')
m,c = np.polyfit(x,y,1)
plt.plot(x, m*x+c)

# %% [markdown]
# ## Multi Variable Linear Regression

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Book2.csv')

# %%
data
# Out:
#   Unnamed: 0  videos  days  subscribers  views
# 0  channel 1      30   150         1800  34000
# 1  channel 2      40   212         1950  41000
# 2  channel 3      50   179         2100  42500
# 3  channel 4      60   346         4300  54300
# 4  channel 5      70   280         4200  56000

# %%
model = LinearRegression();
model.fit(data[['videos','days','subscribers']], data.views)
# Out:
# LinearRegression()

# %%
model.predict([[45, 10, 1000]])
# Out:
# c:\Users\wimuk\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([33579.53544363])
