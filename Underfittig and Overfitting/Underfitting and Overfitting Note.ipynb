# %% [markdown]
# # Underfitting and Overfitting in Machine Learning
#
# Underfitting and overfitting are two common problems that occur when training machine learning models. They describe how well (or poorly) a model learns from the training data and how it generalizes to unseen data.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
